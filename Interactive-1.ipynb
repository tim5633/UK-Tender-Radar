# %% [markdown]
# Connected to audit_fee (Python 3.11.14)

# %%
from __future__ import annotations

import os
import time
from pathlib import Path
from typing import Dict, List

import pandas as pd

from run_tender_radar_mineru import (
    check_mineru_runtime_deps,
    ensure_mineru_cli,
    ensure_companies_csv_from_companies_house,
    is_target_accounts_filing,
    load_active_companies_from_csv,
    run_mineru_extract,
)
from tender_radar import (
    account_filings,
    build_shortlist,
    create_ch_session,
    detect_currency_and_unit,
    document_pdf_url,
    download_pdf,
    extract_audit_fee,
    extract_external_auditor,
    load_api_key_from_file,
    load_dotenv_file,
    make_row,
    parse_year,
    search_companies,
    write_csv,
)

# %%
# Works in both .py and .ipynb: __file__ is not defined in notebooks.
ROOT = Path(__file__).resolve().parent if "__file__" in globals() else Path.cwd()
load_dotenv_file(ROOT / ".env")

COMPANY_SOURCE = "auto-all"
COMPANIES_CSV = ""
MAX_COMPANIES = 0

COMPANY_QUERY = "plc"
# COMPANY_SOURCE = os.getenv("TENDER_COMPANY_SOURCE", "search")  # search | csv | auto-all
COMPANIES_CSV = os.getenv("TENDER_COMPANIES_CSV", "")  # e.g. /path/to/BasicCompanyData-....csv
COMPANIES_CACHE_DIR = Path(
    os.getenv("TENDER_COMPANIES_CACHE_DIR", str(ROOT / "companies_house_cache"))
)
# MAX_COMPANIES = 0  # <=0 means all active companies from selected source
TARGET_COMPANY_KEYWORDS = ["howden joinery group plc"]  # [] means no keyword filter
MAX_FILINGS_PER_COMPANY = 20
SLEEP_SECONDS = 0.25
INCLUDE_ALL_ACCOUNTS = False
PREVIEW_COMPANY_INDEX = 0  # e.g. 3 means companies[3]
RUN_ONLY_PREVIEW_COMPANY = False  # False = process all filtered companies in full-run cell
SAMPLE_ONLY_COMPANY_NUMBER = "02128710"  # Howden Joinery Group PLC

DOWNLOAD_DIR = Path(os.getenv("TENDER_DOWNLOAD_DIR", str(ROOT / "uk_accounts_pdfs")))
PREVIEW_DOWNLOAD_DIR = Path(os.getenv("TENDER_PREVIEW_DOWNLOAD_DIR", str(ROOT / "preview_downloads")))
HISTORY_CSV = Path(os.getenv("TENDER_HISTORY_CSV", str(ROOT / "tender_history.csv")))
SHORTLIST_CSV = Path(os.getenv("TENDER_SHORTLIST_CSV", str(ROOT / "tender_shortlist.csv")))

MINERU_OUTPUT_DIR = Path(os.getenv("TENDER_MINERU_OUTPUT_DIR", str(ROOT / "mineru_outputs")))
MINERU_BACKEND = os.getenv("TENDER_MINERU_BACKEND", "pipeline")
MINERU_METHOD = os.getenv("TENDER_MINERU_METHOD", "auto")
MINERU_LANG = os.getenv("TENDER_MINERU_LANG", "")
MINERU_DEVICE = os.getenv("TENDER_MINERU_DEVICE", "")
MINERU_FORMULA = os.getenv("TENDER_MINERU_FORMULA", "false").lower() != "false"
MINERU_TABLE = os.getenv("TENDER_MINERU_TABLE", "true").lower() != "false"
MINERU_SOURCE = os.getenv("TENDER_MINERU_SOURCE", "")
MINERU_FORCE_REFRESH = False

API_KEY_FILE = Path(os.getenv("CH_API_KEY_FILE", str(ROOT / "ch_api_key.txt")))
API_KEY = os.getenv("CH_API_KEY") or load_api_key_from_file(API_KEY_FILE)

print(f"ROOT={ROOT}")
print(f"COMPANY_SOURCE={COMPANY_SOURCE}")
print(f"COMPANIES_CSV={COMPANIES_CSV or '(not set)'}")
print(f"COMPANIES_CACHE_DIR={COMPANIES_CACHE_DIR}")
print(f"TARGET_COMPANY_KEYWORDS={TARGET_COMPANY_KEYWORDS}")
print(f"DOWNLOAD_DIR={DOWNLOAD_DIR}")
print(f"PREVIEW_DOWNLOAD_DIR={PREVIEW_DOWNLOAD_DIR}")
print(f"HISTORY_CSV={HISTORY_CSV}")
print(f"SHORTLIST_CSV={SHORTLIST_CSV}")
print(f"RUN_ONLY_PREVIEW_COMPANY={RUN_ONLY_PREVIEW_COMPANY}")
print(f"SAMPLE_ONLY_COMPANY_NUMBER={SAMPLE_ONLY_COMPANY_NUMBER}")
print(f"MINERU_BACKEND={MINERU_BACKEND}, METHOD={MINERU_METHOD}, DEVICE={MINERU_DEVICE or 'auto'}")
# Out:
# ROOT=/Users/timliu/Documents/GitHub/UK-Tender-Radar
# COMPANY_SOURCE=auto-all
# COMPANIES_CSV=(not set)
# COMPANIES_CACHE_DIR=/Users/timliu/Documents/GitHub/UK-Tender-Radar/companies_house_cache
# TARGET_COMPANY_KEYWORDS=['howden joinery group plc']
# DOWNLOAD_DIR=/Users/timliu/Documents/GitHub/UK-Tender-Radar/uk_accounts_pdfs
# PREVIEW_DOWNLOAD_DIR=/Users/timliu/Documents/GitHub/UK-Tender-Radar/preview_downloads
# HISTORY_CSV=/Users/timliu/Documents/GitHub/UK-Tender-Radar/tender_history.csv
# SHORTLIST_CSV=/Users/timliu/Documents/GitHub/UK-Tender-Radar/tender_shortlist.csv
# RUN_ONLY_PREVIEW_COMPANY=False
# SAMPLE_ONLY_COMPANY_NUMBER=02128710
# MINERU_BACKEND=pipeline, METHOD=auto, DEVICE=auto

# %%
if not ensure_mineru_cli():
    raise RuntimeError('MinerU CLI not found. Install: uv pip install -U "mineru[all]"')
missing = check_mineru_runtime_deps()
if missing:
    raise RuntimeError(f"Missing MinerU runtime deps: {missing}. Install in current env first.")

if not API_KEY:
    raise RuntimeError("Missing API key. Set CH_API_KEY in .env or provide ch_api_key.txt")

print("Pre-flight checks passed.")
# Out:
# Pre-flight checks passed.

# %%
session, headers = create_ch_session(API_KEY)
if COMPANY_SOURCE == "csv":
    if not COMPANIES_CSV:
        raise RuntimeError("COMPANY_SOURCE='csv' requires COMPANIES_CSV to be set.")
    print(f"Company source: csv ({COMPANIES_CSV})")
    companies = load_active_companies_from_csv(Path(COMPANIES_CSV), max_companies=MAX_COMPANIES)
elif COMPANY_SOURCE == "auto-all":
    print("Company source: auto-all (download latest Companies House BasicCompanyData)")
    csv_path = ensure_companies_csv_from_companies_house(COMPANIES_CACHE_DIR)
    print(f"Using Companies House bulk CSV: {csv_path}")
    companies = load_active_companies_from_csv(csv_path, max_companies=MAX_COMPANIES)
else:
    print(f"Company source: search (query={COMPANY_QUERY})")
    companies = search_companies(
        session=session,
        headers=headers,
        sleep_seconds=SLEEP_SECONDS,
        query=COMPANY_QUERY,
        limit=MAX_COMPANIES,
    )

print(f"Found active companies: {len(companies)}")
# for i, c in enumerate(companies, start=1):
#     print(f"{i:02d}. {c.get('company_number')} | {c.get('title')}")
# Out:
# Company source: auto-all (download latest Companies House BasicCompanyData)
# Using Companies House bulk CSV: /Users/timliu/Documents/GitHub/UK-Tender-Radar/companies_house_cache/BasicCompanyDataAsOneFile-2026-03-02/home/bulkdata/scripts/temp/217/BasicCompanyDataAsOneFile-2026-03-02.csv
# Found active companies: 5156695

# %%
if TARGET_COMPANY_KEYWORDS:
    keys = [k.strip().lower() for k in TARGET_COMPANY_KEYWORDS if k.strip()]
    filtered_companies = []
    for c in companies:
        title = str(c.get("title") or "").lower()
        if any(k in title for k in keys):
            filtered_companies.append(c)
    companies = filtered_companies
    print(f"After keyword filter: {len(companies)}")
    for c in companies[:20]:
        print(f"- {c.get('company_number')} | {c.get('title')}")
# Out:
# After keyword filter: 1
# - 02128710 | HOWDEN JOINERY GROUP PLC

# %%
if not companies:
    raise RuntimeError("No companies found. Try another COMPANY_QUERY.")

if PREVIEW_COMPANY_INDEX < 0 or PREVIEW_COMPANY_INDEX >= len(companies):
    raise RuntimeError(f"PREVIEW_COMPANY_INDEX out of range: {PREVIEW_COMPANY_INDEX}")

company_filings_by_number: Dict[str, List[Dict[str, str]]] = {}
for c in companies:
    company_number = str(c.get("company_number") or "")
    if not company_number:
        continue
    filings = account_filings(
        session=session,
        headers=headers,
        sleep_seconds=SLEEP_SECONDS,
        company_number=company_number,
        limit=MAX_FILINGS_PER_COMPANY,
        include_all_accounts=True,
    )
    filings = [f for f in filings if is_target_accounts_filing(f)]
    company_filings_by_number[company_number] = filings

print(f"Companies to inspect: {len(companies)}")
company_filing_summary_rows: List[Dict[str, str]] = []
company_filing_detail_rows: List[Dict[str, str]] = []
for c in companies:
    n = str(c.get("company_number") or "")
    name = str(c.get("title") or n)
    filings = company_filings_by_number.get(n, [])
    company_filing_summary_rows.append(
        {
            "company_number": n,
            "company": name,
            "filings_count": len(filings),
        }
    )
    print(f"{n} | {name} | filings={len(filings)}")
    for f in filings:
        company_filing_detail_rows.append(
            {
                "company_number": n,
                "company": name,
                "filing_date": str(f.get("date") or ""),
                "filing_type": str(f.get("type") or ""),
                "description": str(f.get("description") or ""),
            }
        )
        print(f"- {f.get('date')} | {f.get('type')} | {f.get('description')}")
    print("")

company_filing_summary_df = pd.DataFrame(company_filing_summary_rows)
company_filing_details_df = pd.DataFrame(company_filing_detail_rows)
print("company_filing_summary_df:")
display(company_filing_summary_df)
print("company_filing_details_df (head 100):")
display(company_filing_details_df.head(100))

first_company = companies[PREVIEW_COMPANY_INDEX]
first_number = str(first_company.get("company_number") or "")
first_name = str(first_company.get("title") or first_number)
first_filings = company_filings_by_number.get(first_number, [])
print(f"Preview company (index {PREVIEW_COMPANY_INDEX}): {first_number} | {first_name}")
# Out:
# Companies to inspect: 1
# 02128710 | HOWDEN JOINERY GROUP PLC | filings=20
# - 2025-05-19 | AA | accounts-with-accounts-type-group
# - 2024-05-19 | AA | accounts-with-accounts-type-group
# - 2023-05-19 | AA | accounts-with-accounts-type-group
# - 2022-05-24 | AA | accounts-with-accounts-type-group
# - 2021-06-03 | AA | accounts-with-accounts-type-group
# - 2020-06-10 | AA | accounts-with-accounts-type-group
# - 2019-07-25 | AA | accounts-with-accounts-type-group
# - 2019-07-23 | AA | accounts-with-accounts-type-group
# - 2017-05-17 | AA | accounts-with-accounts-type-group
# - 2016-05-13 | AA | accounts-with-accounts-type-group
# - 2015-05-30 | AA | accounts-with-accounts-type-group
# - 2014-05-06 | AA | accounts-with-accounts-type-group
# - 2013-04-19 | AA | accounts-with-accounts-type-group
# - 2012-04-05 | AA | accounts-with-accounts-type-group
# - 2011-06-13 | AA | accounts-with-accounts-type-group
# - 2010-05-17 | AA | accounts-with-accounts-type-group
# - 2009-04-17 | AA | accounts-with-accounts-type-group
# - 2008-03-29 | AA | accounts-with-accounts-type-group
# - 2007-06-14 | AA | accounts-with-accounts-type-group
# - 2006-08-17 | AA | accounts-with-accounts-type-group
#
# company_filing_summary_df:
#   company_number                   company  filings_count
# 0       02128710  HOWDEN JOINERY GROUP PLC             20
# company_filing_details_df (head 100):
#    company_number                   company filing_date filing_type  \
# 0        02128710  HOWDEN JOINERY GROUP PLC  2025-05-19          AA
# 1        02128710  HOWDEN JOINERY GROUP PLC  2024-05-19          AA
# 2        02128710  HOWDEN JOINERY GROUP PLC  2023-05-19          AA
# 3        02128710  HOWDEN JOINERY GROUP PLC  2022-05-24          AA
# 4        02128710  HOWDEN JOINERY GROUP PLC  2021-06-03          AA
# 5        02128710  HOWDEN JOINERY GROUP PLC  2020-06-10          AA
# 6        02128710  HOWDEN JOINERY GROUP PLC  2019-07-25          AA
# 7        02128710  HOWDEN JOINERY GROUP PLC  2019-07-23          AA
# 8        02128710  HOWDEN JOINERY GROUP PLC  2017-05-17          AA
# 9        02128710  HOWDEN JOINERY GROUP PLC  2016-05-13          AA
# 10       02128710  HOWDEN JOINERY GROUP PLC  2015-05-30          AA
# 11       02128710  HOWDEN JOINERY GROUP PLC  2014-05-06          AA
# 12       02128710  HOWDEN JOINERY GROUP PLC  2013-04-19          AA
# 13       02128710  HOWDEN JOINERY GROUP PLC  2012-04-05          AA
# 14       02128710  HOWDEN JOINERY GROUP PLC  2011-06-13          AA
# 15       02128710  HOWDEN JOINERY GROUP PLC  2010-05-17          AA
# 16       02128710  HOWDEN JOINERY GROUP PLC  2009-04-17          AA
# 17       02128710  HOWDEN JOINERY GROUP PLC  2008-03-29          AA
# 18       02128710  HOWDEN JOINERY GROUP PLC  2007-06-14          AA
# 19       02128710  HOWDEN JOINERY GROUP PLC  2006-08-17          AA
#
#                           description
# 0   accounts-with-accounts-type-group
# 1   accounts-with-accounts-type-group
# 2   accounts-with-accounts-type-group
# 3   accounts-with-accounts-type-group
# 4   accounts-with-accounts-type-group
# 5   accounts-with-accounts-type-group
# 6   accounts-with-accounts-type-group
# 7   accounts-with-accounts-type-group
# 8   accounts-with-accounts-type-group
# 9   accounts-with-accounts-type-group
# 10  accounts-with-accounts-type-group
# 11  accounts-with-accounts-type-group
# 12  accounts-with-accounts-type-group
# 13  accounts-with-accounts-type-group
# 14  accounts-with-accounts-type-group
# 15  accounts-with-accounts-type-group
# 16  accounts-with-accounts-type-group
# 17  accounts-with-accounts-type-group
# 18  accounts-with-accounts-type-group
# 19  accounts-with-accounts-type-group
# Preview company (index 0): 02128710 | HOWDEN JOINERY GROUP PLC

# %%
PREVIEW_DOWNLOAD_DIR.mkdir(parents=True, exist_ok=True)
downloaded_rows: List[Dict[str, str]] = []
for c in companies:
    company_number = str(c.get("company_number") or "")
    company_name = str(c.get("title") or company_number)
    filings = company_filings_by_number.get(company_number, [])
    for filing in filings:
        filing_date = str(filing.get("date") or "")
        meta_url = filing.get("links", {}).get("document_metadata")
        if not meta_url:
            continue
        pdf_url = document_pdf_url(session=session, headers=headers, document_metadata_url=str(meta_url))
        if not pdf_url:
            continue

        preview_pdf_path = PREVIEW_DOWNLOAD_DIR / f"{company_number}_{filing_date}.pdf"
        downloaded = True
        if not preview_pdf_path.exists():
            downloaded = download_pdf(session=session, headers=headers, pdf_url=pdf_url, output_path=preview_pdf_path)
        if downloaded:
            downloaded_rows.append(
                {
                    "company_number": company_number,
                    "company": company_name,
                    "filing_date": filing_date,
                    "pdf_path": str(preview_pdf_path),
                }
            )

print(f"Preview folder: {PREVIEW_DOWNLOAD_DIR}")
print(f"Downloaded/ready files: {len(downloaded_rows)}")
downloaded_files_df = pd.DataFrame(downloaded_rows)
display(downloaded_files_df.head(200))
# Out:
# Preview folder: /Users/timliu/Documents/GitHub/UK-Tender-Radar/preview_downloads
# Downloaded/ready files: 20
#    company_number                   company filing_date  \
# 0        02128710  HOWDEN JOINERY GROUP PLC  2025-05-19
# 1        02128710  HOWDEN JOINERY GROUP PLC  2024-05-19
# 2        02128710  HOWDEN JOINERY GROUP PLC  2023-05-19
# 3        02128710  HOWDEN JOINERY GROUP PLC  2022-05-24
# 4        02128710  HOWDEN JOINERY GROUP PLC  2021-06-03
# 5        02128710  HOWDEN JOINERY GROUP PLC  2020-06-10
# 6        02128710  HOWDEN JOINERY GROUP PLC  2019-07-25
# 7        02128710  HOWDEN JOINERY GROUP PLC  2019-07-23
# 8        02128710  HOWDEN JOINERY GROUP PLC  2017-05-17
# 9        02128710  HOWDEN JOINERY GROUP PLC  2016-05-13
# 10       02128710  HOWDEN JOINERY GROUP PLC  2015-05-30
# 11       02128710  HOWDEN JOINERY GROUP PLC  2014-05-06
# 12       02128710  HOWDEN JOINERY GROUP PLC  2013-04-19
# 13       02128710  HOWDEN JOINERY GROUP PLC  2012-04-05
# 14       02128710  HOWDEN JOINERY GROUP PLC  2011-06-13
# 15       02128710  HOWDEN JOINERY GROUP PLC  2010-05-17
# 16       02128710  HOWDEN JOINERY GROUP PLC  2009-04-17
# 17       02128710  HOWDEN JOINERY GROUP PLC  2008-03-29
# 18       02128710  HOWDEN JOINERY GROUP PLC  2007-06-14
# 19       02128710  HOWDEN JOINERY GROUP PLC  2006-08-17
#
#                                              pdf_path
# 0   /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 1   /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 2   /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 3   /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 4   /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 5   /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 6   /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 7   /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 8   /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 9   /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 10  /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 11  /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 12  /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 13  /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 14  /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 15  /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 16  /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 17  /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 18  /Users/timliu/Documents/GitHub/UK-Tender-Radar...
# 19  /Users/timliu/Documents/GitHub/UK-Tender-Radar...

# %%
sample_batch_start_ts = time.time()
sample_extraction_rows: List[Dict[str, str]] = []
sample_output_dirs: Dict[str, Path] = {}

sample_companies = [
    c for c in companies if str(c.get("company_number") or "") == SAMPLE_ONLY_COMPANY_NUMBER
]
if not sample_companies:
    raise RuntimeError(f"SAMPLE_ONLY_COMPANY_NUMBER not found in current companies: {SAMPLE_ONLY_COMPANY_NUMBER}")

for c in sample_companies:
    company_start_ts = time.time()
    company_number = str(c.get("company_number") or "")
    company_name = str(c.get("title") or company_number)
    filings = company_filings_by_number.get(company_number, [])
    if not filings:
        continue

    sample_filing = filings[0]
    sample_date = str(sample_filing.get("date") or "")
    sample_meta_url = sample_filing.get("links", {}).get("document_metadata")
    if not sample_meta_url:
        continue
    sample_pdf_url = document_pdf_url(session=session, headers=headers, document_metadata_url=str(sample_meta_url))
    if not sample_pdf_url:
        continue

    sample_pdf_path = DOWNLOAD_DIR / f"{company_number}_{sample_date}.pdf"
    if not sample_pdf_path.exists():
        ok = download_pdf(session=session, headers=headers, pdf_url=sample_pdf_url, output_path=sample_pdf_path)
        if not ok:
            continue

    sample_output_dir = MINERU_OUTPUT_DIR / f"{company_number}_{sample_date}"
    sample_output_dirs[company_number] = sample_output_dir
    sample_text = run_mineru_extract(
        pdf_path=sample_pdf_path,
        output_dir=sample_output_dir,
        backend=MINERU_BACKEND,
        method=MINERU_METHOD,
        lang=MINERU_LANG,
        force_refresh=MINERU_FORCE_REFRESH,
        device=MINERU_DEVICE,
        formula=MINERU_FORMULA,
        table=MINERU_TABLE,
        source=MINERU_SOURCE,
    )
    if not sample_text:
        sample_extraction_rows.append(
            {
                "company_number": company_number,
                "company": company_name,
                "filing_date": sample_date,
                "status": "failed",
                "log_path": str(sample_output_dir / "mineru_stderr.log"),
                "runtime_seconds": round(time.time() - company_start_ts, 2),
            }
        )
        continue

    sample_auditor, sample_conf = extract_external_auditor(sample_text)
    sample_fee, _ = extract_audit_fee(sample_text)
    sample_currency, sample_unit = detect_currency_and_unit(sample_text)
    sample_year = parse_year(sample_date, sample_text)
    sample_extraction_rows.append(
        {
            "company_number": company_number,
            "company": company_name,
            "filing_date": sample_date,
            "year": sample_year,
            "external_auditor": sample_auditor,
            "audit_fee": sample_fee,
            "fee_unit": sample_unit,
            "currency": sample_currency,
            "confidence": sample_conf,
            "status": "ok",
            "pdf_path": str(sample_pdf_path),
            "runtime_seconds": round(time.time() - company_start_ts, 2),
        }
    )

sample_extraction_df = pd.DataFrame(sample_extraction_rows)
display(sample_extraction_df)
sample_batch_elapsed = time.time() - sample_batch_start_ts
print(f"[SAMPLE] companies_processed={len(sample_extraction_rows)} runtime_seconds={sample_batch_elapsed:.2f}")
print(f"[SAMPLE] runtime_minutes={sample_batch_elapsed / 60:.2f}")


# # %% 9) Debug MinerU logs for failed sample rows
# if "sample_extraction_df" not in globals() or sample_extraction_df.empty:
#     print("No sample_extraction_df found.")
# else:
#     failed = sample_extraction_df[sample_extraction_df["status"] != "ok"]
#     if failed.empty:
#         print("No failed sample rows.")
#     else:
#         display(failed)
#         for _, row in failed.iterrows():
#             company_number = str(row["company_number"])
#             filing_date = str(row["filing_date"])
#             out_dir = MINERU_OUTPUT_DIR / f"{company_number}_{filing_date}"
#             sample_stdout_log = out_dir / "mineru_stdout.log"
#             sample_stderr_log = out_dir / "mineru_stderr.log"
#             print(f"\n=== {company_number} {filing_date} ===")
#             print(f"stdout log: {sample_stdout_log}")
#             print(f"stderr log: {sample_stderr_log}")
#             if sample_stderr_log.exists():
#                 err_lines = sample_stderr_log.read_text(encoding='utf-8', errors='ignore').splitlines()
#                 print(f"[stderr] lines={len(err_lines)}")
#                 for ln in err_lines[-80:]:
#                     print(ln)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 37
#      35 sample_output_dir = MINERU_OUTPUT_DIR / f"{company_number}_{sample_date}"
#      36 sample_output_dirs[company_number] = sample_output_dir
# ---> 37 sample_text = run_mineru_extract(
#      38     pdf_path=sample_pdf_path,
#      39     output_dir=sample_output_dir,
#      40     backend=MINERU_BACKEND,
#      41     method=MINERU_METHOD,
#      42     lang=MINERU_LANG,
#      43     force_refresh=MINERU_FORCE_REFRESH,
#      44     device=MINERU_DEVICE,
#      45     formula=MINERU_FORMULA,
#      46     table=MINERU_TABLE,
#      47     source=MINERU_SOURCE,
#      48 )
#      49 if not sample_text:
#      50     sample_extraction_rows.append(
#      51         {
#      52             "company_number": company_number,
#    (...)     58         }
#      59     )
#
# File ~/Documents/GitHub/UK-Tender-Radar/run_tender_radar_mineru.py:448, in run_mineru_extract(pdf_path, output_dir, backend, method, lang, force_refresh, device, formula, table, source)
#     445     proc = subprocess.run(cmd, capture_output=True, text=True)
#     446     return proc.returncode, proc.stdout or "", proc.stderr or ""
# --> 448 rc, out, err = _run_once(pdf_path, method, formula, table)
#     449 text = _load_markdown_text(output_dir) or _load_content_list_text(output_dir) or _load_plain_text(output_dir)
#     450 if rc == 0 and text:
#
# File ~/Documents/GitHub/UK-Tender-Radar/run_tender_radar_mineru.py:445, in run_mineru_extract.<locals>._run_once(path_to_pdf, run_method, run_formula, run_table)
#     433 def _run_once(path_to_pdf: Path, run_method: str, run_formula: bool, run_table: bool) -> tuple[int, str, str]:
#     434     cmd = build_mineru_cmd(
#     435         path_to_pdf,
#     436         output_dir,
#    (...)    443         source=source,
#     444     )
# --> 445     proc = subprocess.run(cmd, capture_output=True, text=True)
#     446     return proc.returncode, proc.stdout or "", proc.stderr or ""
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/subprocess.py:2115, in Popen._communicate(self, input, endtime, orig_timeout)
#    2108     self._check_timeout(endtime, orig_timeout,
#    2109                         stdout, stderr,
#    2110                         skip_check_and_raise=True)
#    2111     raise RuntimeError(  # Impossible :)
#    2112         '_check_timeout(..., skip_check_and_raise=True) '
#    2113         'failed to raise TimeoutExpired.')
# -> 2115 ready = selector.select(timeout)
#    2116 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2118 # XXX Rewrite these to use non-blocking I/O on the file
#    2119 # objects; they are no longer using C stdio!
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
start_ts = time.time()
history_rows: List[Dict[str, str]] = []

run_companies = [first_company] if RUN_ONLY_PREVIEW_COMPANY else companies
for c in run_companies:
    company_number = str(c.get("company_number") or "")
    if not company_number:
        continue
    company_name = str(c.get("title") or company_number)

    filings = account_filings(
        session=session,
        headers=headers,
        sleep_seconds=SLEEP_SECONDS,
        company_number=company_number,
        limit=MAX_FILINGS_PER_COMPANY,
        include_all_accounts=True,
    )
    for filing in filings:
        if not is_target_accounts_filing(filing):
            continue
        filing_date = str(filing.get("date") or "")
        meta_url = filing.get("links", {}).get("document_metadata")
        if not meta_url:
            continue

        pdf_url = document_pdf_url(session=session, headers=headers, document_metadata_url=str(meta_url))
        if not pdf_url:
            continue

        pdf_path = DOWNLOAD_DIR / f"{company_number}_{filing_date}.pdf"
        if not pdf_path.exists():
            ok = download_pdf(session=session, headers=headers, pdf_url=pdf_url, output_path=pdf_path)
            if not ok:
                continue

        per_pdf_output = MINERU_OUTPUT_DIR / f"{company_number}_{filing_date}"
        text = run_mineru_extract(
            pdf_path=pdf_path,
            output_dir=per_pdf_output,
            backend=MINERU_BACKEND,
            method=MINERU_METHOD,
            lang=MINERU_LANG,
            force_refresh=MINERU_FORCE_REFRESH,
            device=MINERU_DEVICE,
            formula=MINERU_FORMULA,
            table=MINERU_TABLE,
            source=MINERU_SOURCE,
        )
        if not text:
            continue

        auditor, confidence = extract_external_auditor(text)
        audit_fee, _ = extract_audit_fee(text)
        currency, fee_unit = detect_currency_and_unit(text)
        year = parse_year(filing_date, text)

        history_rows.append(
            make_row(
                company_number=company_number,
                company=company_name,
                year=year,
                external_auditor=auditor,
                audit_fee=audit_fee,
                fee_unit=fee_unit,
                currency=currency,
                filing_date=filing_date,
                confidence=confidence,
                pdf_path=str(pdf_path),
            )
        )

history_rows.sort(key=lambda r: (r.get("company_number", ""), r.get("year", "")), reverse=True)
shortlist_rows = build_shortlist(history_rows)
history_df = pd.DataFrame(history_rows)
shortlist_df = pd.DataFrame(shortlist_rows)

write_csv(
    HISTORY_CSV,
    history_rows,
    [
        "company_number",
        "company",
        "year",
        "external_auditor",
        "audit_fee",
        "fee_unit",
        "currency",
        "filing_date",
        "confidence",
        "pdf_path",
    ],
)
write_csv(
    SHORTLIST_CSV,
    shortlist_rows,
    [
        "company_number",
        "company",
        "current_external_auditor",
        "continuous_tenure_years",
        "latest_audit_fee_gbp",
        "priority_score",
        "tender_status",
    ],
)

elapsed = time.time() - start_ts
print(f"[DONE] history CSV: {HISTORY_CSV}")
print(f"[DONE] shortlist CSV: {SHORTLIST_CSV}")
print(f"[DONE] rows: history={len(history_rows)} shortlist={len(shortlist_rows)}")
print(f"[DONE] runtime_seconds: {elapsed:.2f}")
print(f"[DONE] runtime_minutes: {elapsed / 60:.2f}")
display(history_df.head(200))
display(shortlist_df)
# Out:
# Cell was canceled due to an error in a previous cell.

# %%
sample_companies
# Out:
# [{'company_number': '02128710',
#   'title': 'HOWDEN JOINERY GROUP PLC',
#   'company_status': 'active'}]

# %%
company_filings_by_number
# Out:
# {'02128710': [{'transaction_id': 'MzQ2NjY5NzY5M2FkaXF6a2N4',
#    'barcode': 'AE2M63X5',
#    'type': 'AA',
#    'date': '2025-05-19',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2024-12-28'},
#    'pages': 232,
#    'action_date': '2024-12-28',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzQ2NjY5NzY5M2FkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/GK2NdXmGWyjtvOpERSJtiiefBNSedMmd4qD2woW1rHc'}},
#   {'transaction_id': 'MzQyMjE0Mzc2N2FkaXF6a2N4',
#    'barcode': 'AD368Z95',
#    'type': 'AA',
#    'date': '2024-05-19',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2023-12-30'},
#    'pages': 220,
#    'action_date': '2023-12-30',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzQyMjE0Mzc2N2FkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/Kbmt5ZNkpj7ivpE2eSHeGci-YkXLwpXnhkp4bmWSZ74'}},
#   {'transaction_id': 'MzM3OTI2MTQ5MWFkaXF6a2N4',
#    'barcode': 'AC35HVOO',
#    'type': 'AA',
#    'date': '2023-05-19',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2022-12-24'},
#    'pages': 219,
#    'action_date': '2022-12-24',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzM3OTI2MTQ5MWFkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/s6_MkakOXQG9wMgjO4a1dgg_yQ-zxuogBNTPwLpa9QI'}},
#   {'transaction_id': 'MzM0MDI2MDc2MGFkaXF6a2N4',
#    'barcode': 'AB4ES0J7',
#    'type': 'AA',
#    'date': '2022-05-24',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2021-12-31'},
#    'pages': 207,
#    'action_date': '2021-12-31',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzM0MDI2MDc2MGFkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/NSOJkPdivqYC31qnxCiPaoFTzxKLsBBFmwi_lrx8UKg'}},
#   {'transaction_id': 'MzMwMjMwODk2MGFkaXF6a2N4',
#    'barcode': 'AA4T0E63',
#    'type': 'AA',
#    'date': '2021-06-03',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2020-12-26'},
#    'pages': 201,
#    'action_date': '2020-12-26',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzMwMjMwODk2MGFkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/fSjNfCgBLmsOKM-CQS8eu8_FBl9Nm7DMa1yuACN4l38'}},
#   {'transaction_id': 'MzI2Njg4ODU3NWFkaXF6a2N4',
#    'barcode': 'A96J7C68',
#    'type': 'AA',
#    'date': '2020-06-10',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2019-12-31'},
#    'pages': 181,
#    'action_date': '2019-12-31',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzI2Njg4ODU3NWFkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/fSrdTLPxa0icIgiWEv4gTaEpXCB8ppTowxLtLyWfoyk'}},
#   {'transaction_id': 'MzI0MDE5MjI4MGFkaXF6a2N4',
#    'barcode': 'A75OVN21',
#    'type': 'AA',
#    'date': '2019-07-25',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2017-12-30'},
#    'pages': 144,
#    'action_date': '2017-12-30',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzI0MDE5MjI4MGFkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/j4aAk7C9hwXeACMYfDacx6fQJv-lvb1YSg12g9ver5w'}},
#   {'transaction_id': 'MzIzOTk3NzQyM2FkaXF6a2N4',
#    'barcode': 'A8514AEW',
#    'type': 'AA',
#    'date': '2019-07-23',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2018-12-29'},
#    'pages': 164,
#    'action_date': '2018-12-29',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzIzOTk3NzQyM2FkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/lbi5uPj5xXf94dH1nYGzTgg7yAHnRQZOGZDGzgm17c0'}},
#   {'transaction_id': 'MzE3NTk3NzkwMGFkaXF6a2N4',
#    'barcode': 'A65WEXAY',
#    'type': 'AA',
#    'date': '2017-05-17',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2016-12-24'},
#    'pages': 135,
#    'action_date': '2016-12-24',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzE3NTk3NzkwMGFkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/p5j6oc3i9v0M9sUPO7v1j9NPRl0jad16_hxDvC9qSCA'}},
#   {'transaction_id': 'MzE0ODQ2MTk0N2FkaXF6a2N4',
#    'barcode': 'A56I44R6',
#    'type': 'AA',
#    'date': '2016-05-13',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2015-12-26'},
#    'pages': 138,
#    'action_date': '2015-12-26',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzE0ODQ2MTk0N2FkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/nv8zTNdFR0I4PKY5JMXoCn6pIV_Cpdex8onoXCWVy_0'}},
#   {'transaction_id': 'MzEyMzg5MzE5NWFkaXF6a2N4',
#    'barcode': 'A47TO6IY',
#    'type': 'AA',
#    'date': '2015-05-30',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2014-12-27'},
#    'pages': 128,
#    'action_date': '2014-12-27',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzEyMzg5MzE5NWFkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/vDRM2AVXcokkzMwr7W4J2Jn7XhefmBcHTZs6wdc3PCQ'}},
#   {'transaction_id': 'MzEwMjc1OTc1MmFkaXF6a2N4',
#    'barcode': 'A35VQEZ5',
#    'type': 'AA',
#    'date': '2014-05-06',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2013-12-28'},
#    'pages': 133,
#    'action_date': '2013-12-28',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzEwMjc1OTc1MmFkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/Ad_b9jByVHputVXD4rFZWO08pv6ilxwrI9dpa-9I6Wc'}},
#   {'transaction_id': 'MzA3NjUxNDQzOWFkaXF6a2N4',
#    'barcode': 'A26BDXSX',
#    'type': 'AA',
#    'date': '2013-04-19',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2012-12-29'},
#    'pages': 122,
#    'action_date': '2012-12-29',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzA3NjUxNDQzOWFkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/hyEGRvbnIFuCsZ6-07CJmf_NY_toyuVaNxgkv3EnLlc'}},
#   {'transaction_id': 'MzA1NTQxMjg2NmFkaXF6a2N4',
#    'barcode': 'E0ZIKZBT',
#    'type': 'AA',
#    'date': '2012-04-05',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2011-12-24'},
#    'pages': 122,
#    'action_date': '2011-12-24',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzA1NTQxMjg2NmFkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/bcLKvXK5M2oKAUO9iDKQtpMgWHLoFVAHJvVjLBWLcZA'}},
#   {'transaction_id': 'MzAzODc0Njg4NWFkaXF6a2N4',
#    'barcode': 'A6VPOUVD',
#    'type': 'AA',
#    'date': '2011-06-13',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2010-12-25'},
#    'pages': 119,
#    'action_date': '2010-12-25',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzAzODc0Njg4NWFkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/nDLzUn_YFhRBPNaq1QqpvT2Rcxzr-enpvp814478CQY'}},
#   {'transaction_id': 'MzAxNTY3MzE3MmFkaXF6a2N4',
#    'barcode': 'AZFGQJXA',
#    'type': 'AA',
#    'date': '2010-05-17',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2009-12-27'},
#    'pages': 115,
#    'action_date': '2009-12-27',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MzAxNTY3MzE3MmFkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/0yBPbHf9JHybo7VyXZeb2jEd5v2a4dXbm4mUUlKl45o'}},
#   {'transaction_id': 'MjAzMDgxNTA1NGFkaXF6a2N4',
#    'barcode': 'A3ZEF91F',
#    'type': 'AA',
#    'date': '2009-04-17',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2008-12-27'},
#    'pages': 117,
#    'action_date': '2008-12-27',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MjAzMDgxNTA1NGFkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/xC3wP4xFQIPGBknAZeNuQRJIyep60GtquP8TXKgQuEg'}},
#   {'transaction_id': 'MjAwMjI2OTk1OGFkaXF6a2N4',
#    'barcode': 'ABO92YDV',
#    'type': 'AA',
#    'date': '2008-03-29',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2007-12-29'},
#    'pages': 104,
#    'action_date': '2007-12-29',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MjAwMjI2OTk1OGFkaXF6a2N4',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/rSO1REB55l4f74tjHzl_uYH2R0W4-kY5DOsqrZZdkUI'}},
#   {'transaction_id': 'MTgyMDExMjAwYWRpcXprY3g',
#    'type': 'AA',
#    'date': '2007-06-14',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2006-12-31'},
#    'pages': 127,
#    'action_date': '2006-12-31',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MTgyMDExMjAwYWRpcXprY3g',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/9iVBb0O-nqS4uUUdk2iP9e5r5eLnpJbEsAdp1lOncS4'}},
#   {'transaction_id': 'MTY0MDQzMzcwYWRpcXprY3g',
#    'type': 'AA',
#    'date': '2006-08-17',
#    'category': 'accounts',
#    'description': 'accounts-with-accounts-type-group',
#    'description_values': {'made_up_date': '2005-12-24'},
#    'pages': 88,
#    'action_date': '2005-12-24',
#    'paper_filed': True,
#    'links': {'self': '/company/02128710/filing-history/MTY0MDQzMzcwYWRpcXprY3g',
#     'document_metadata': 'https://document-api.company-information.service.gov.uk/document/xa5dOaQ6oriiDarY5IyJzI84jTD3OFsVff1zWWIcdp8'}}]}

# %%
SAMPLE_ONLY_COMPANY_NUMBER = "02128710"
MINERU_METHOD = "txt"
MINERU_FORMULA = False
MINERU_TABLE = False
MINERU_FORCE_REFRESH = False

# %%
# %%time
# Out:
# UsageError: %%time is a cell magic, but the cell body is empty. Did you mean the line magic %time (single %)?

# %%
# %%time
sample_batch_start_ts = time.time()
sample_extraction_rows: List[Dict[str, str]] = []
sample_output_dirs: Dict[str, Path] = {}

sample_companies = [
    c for c in companies if str(c.get("company_number") or "") == SAMPLE_ONLY_COMPANY_NUMBER
]
if not sample_companies:
    raise RuntimeError(f"SAMPLE_ONLY_COMPANY_NUMBER not found in current companies: {SAMPLE_ONLY_COMPANY_NUMBER}")

for c in sample_companies:
    company_start_ts = time.time()
    company_number = str(c.get("company_number") or "")
    company_name = str(c.get("title") or company_number)
    filings = company_filings_by_number.get(company_number, [])
    if not filings:
        continue

    sample_filing = filings[0]
    sample_date = str(sample_filing.get("date") or "")
    sample_meta_url = sample_filing.get("links", {}).get("document_metadata")
    if not sample_meta_url:
        continue
    sample_pdf_url = document_pdf_url(session=session, headers=headers, document_metadata_url=str(sample_meta_url))
    if not sample_pdf_url:
        continue

    sample_pdf_path = DOWNLOAD_DIR / f"{company_number}_{sample_date}.pdf"
    if not sample_pdf_path.exists():
        ok = download_pdf(session=session, headers=headers, pdf_url=sample_pdf_url, output_path=sample_pdf_path)
        if not ok:
            continue

    sample_output_dir = MINERU_OUTPUT_DIR / f"{company_number}_{sample_date}"
    sample_output_dirs[company_number] = sample_output_dir
    sample_text = run_mineru_extract(
        pdf_path=sample_pdf_path,
        output_dir=sample_output_dir,
        backend=MINERU_BACKEND,
        method=MINERU_METHOD,
        lang=MINERU_LANG,
        force_refresh=MINERU_FORCE_REFRESH,
        device=MINERU_DEVICE,
        formula=MINERU_FORMULA,
        table=MINERU_TABLE,
        source=MINERU_SOURCE,
    )
    if not sample_text:
        sample_extraction_rows.append(
            {
                "company_number": company_number,
                "company": company_name,
                "filing_date": sample_date,
                "status": "failed",
                "log_path": str(sample_output_dir / "mineru_stderr.log"),
                "runtime_seconds": round(time.time() - company_start_ts, 2),
            }
        )
        continue

    sample_auditor, sample_conf = extract_external_auditor(sample_text)
    sample_fee, _ = extract_audit_fee(sample_text)
    sample_currency, sample_unit = detect_currency_and_unit(sample_text)
    sample_year = parse_year(sample_date, sample_text)
    sample_extraction_rows.append(
        {
            "company_number": company_number,
            "company": company_name,
            "filing_date": sample_date,
            "year": sample_year,
            "external_auditor": sample_auditor,
            "audit_fee": sample_fee,
            "fee_unit": sample_unit,
            "currency": sample_currency,
            "confidence": sample_conf,
            "status": "ok",
            "pdf_path": str(sample_pdf_path),
            "runtime_seconds": round(time.time() - company_start_ts, 2),
        }
    )

sample_extraction_df = pd.DataFrame(sample_extraction_rows)
display(sample_extraction_df)
sample_batch_elapsed = time.time() - sample_batch_start_ts
print(f"[SAMPLE] companies_processed={len(sample_extraction_rows)} runtime_seconds={sample_batch_elapsed:.2f}")
print(f"[SAMPLE] runtime_minutes={sample_batch_elapsed / 60:.2f}")


# # %% 9) Debug MinerU logs for failed sample rows
# if "sample_extraction_df" not in globals() or sample_extraction_df.empty:
#     print("No sample_extraction_df found.")
# else:
#     failed = sample_extraction_df[sample_extraction_df["status"] != "ok"]
#     if failed.empty:
#         print("No failed sample rows.")
#     else:
#         display(failed)
#         for _, row in failed.iterrows():
#             company_number = str(row["company_number"])
#             filing_date = str(row["filing_date"])
#             out_dir = MINERU_OUTPUT_DIR / f"{company_number}_{filing_date}"
#             sample_stdout_log = out_dir / "mineru_stdout.log"
#             sample_stderr_log = out_dir / "mineru_stderr.log"
#             print(f"\n=== {company_number} {filing_date} ===")
#             print(f"stdout log: {sample_stdout_log}")
#             print(f"stderr log: {sample_stderr_log}")
#             if sample_stderr_log.exists():
#                 err_lines = sample_stderr_log.read_text(encoding='utf-8', errors='ignore').splitlines()
#                 print(f"[stderr] lines={len(err_lines)}")
#                 for ln in err_lines[-80:]:
#                     print(ln)
# Out:
# CPU times: user 15.7 ms, sys: 45.7 ms, total: 61.4 ms
# Wall time: 48.7 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'sample_batch_start_ts = time.time()\nsample_extraction_rows: List[Dict[str, str]] = []\nsample_output_dirs: Dict[str, Path] = {}\n\nsample_companies = [\n    c for c in companies if str(c.get("company_number") or "") == SAMPLE_ONLY_COMPANY_NUMBER\n]\nif not sample_companies:\n    raise RuntimeError(f"SAMPLE_ONLY_COMPANY_NUMBER not found in current companies: {SAMPLE_ONLY_COMPANY_NUMBER}")\n\nfor c in sample_companies:\n    company_start_ts = time.time()\n    company_number = str(c.get("company_number") or "")\n    company_name = str(c.get("title") or company_number)\n    filings = company_filings_by_number.get(company_number, [])\n    if not filings:\n        continue\n\n    sample_filing = filings[0]\n    sample_date = str(sample_filing.get("date") or "")\n    sample_meta_url = sample_filing.get("links", {}).get("document_metadata")\n    if not sample_meta_url:\n        continue\n    sample_pdf_url = document_pdf_url(session=session, headers=headers, document_metadata_url=str(sample_meta_url))\n    if not sample_pdf_url:\n        continue\n\n    sample_pdf_path = DOWNLOAD_DIR / f"{company_number}_{sample_date}.pdf"\n    if not sample_pdf_path.exists():\n        ok = download_pdf(session=session, headers=headers, pdf_url=sample_pdf_url, output_path=sample_pdf_path)\n        if not ok:\n            continue\n\n    sample_output_dir = MINERU_OUTPUT_DIR / f"{company_number}_{sample_date}"\n    sample_output_dirs[company_number] = sample_output_dir\n    sample_text = run_mineru_extract(\n        pdf_path=sample_pdf_path,\n        output_dir=sample_output_dir,\n        backend=MINERU_BACKEND,\n        method=MINERU_METHOD,\n        lang=MINERU_LANG,\n        force_refresh=MINERU_FORCE_REFRESH,\n        device=MINERU_DEVICE,\n        formula=MINERU_FORMULA,\n        table=MINERU_TABLE,\n        source=MINERU_SOURCE,\n    )\n    if not sample_text:\n        sample_extraction_rows.append(\n            {\n                "company_number": company_number,\n                "company": company_name,\n                "filing_date": sample_date,\n                "status": "failed",\n                "log_path": str(sample_output_dir / "mineru_stderr.log"),\n                "runtime_seconds": round(time.time() - company_start_ts, 2),\n            }\n        )\n        continue\n\n    sample_auditor, sample_conf = extract_external_auditor(sample_text)\n    sample_fee, _ = extract_audit_fee(sample_text)\n    sample_currency, sample_unit = detect_currency_and_unit(sample_text)\n    sample_year = parse_year(sample_date, sample_text)\n    sample_extraction_rows.append(\n        {\n            "company_number": company_number,\n            "company": company_name,\n            "filing_date": sample_date,\n            "year": sample_year,\n            "external_auditor": sample_auditor,\n            "audit_fee": sample_fee,\n            "fee_unit": sample_unit,\n            "currency": sample_currency,\n            "confidence": sample_conf,\n            "status": "ok",\n            "pdf_path": str(sample_pdf_path),\n            "runtime_seconds": round(time.time() - company_start_ts, 2),\n        }\n    )\n\nsample_extraction_df = pd.DataFrame(sample_extraction_rows)\ndisplay(sample_extraction_df)\nsample_batch_elapsed = time.time() - sample_batch_start_ts\nprint(f"[SAMPLE] companies_processed={len(sample_extraction_rows)} runtime_seconds={sample_batch_elapsed:.2f}")\nprint(f"[SAMPLE] runtime_minutes={sample_batch_elapsed / 60:.2f}")\n\n\n# # %% 9) Debug MinerU logs for failed sample rows\n# if "sample_extraction_df" not in globals() or sample_extraction_df.empty:\n#     print("No sample_extraction_df found.")\n# else:\n#     failed = sample_extraction_df[sample_extraction_df["status"] != "ok"]\n#     if failed.empty:\n#         print("No failed sample rows.")\n#     else:\n#         display(failed)\n#         for _, row in failed.iterrows():\n#             company_number = str(row["company_number"]) ...
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2572, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2570 with self.builtin_trap:
#    2571     args = (magic_arg_s, cell)
# -> 2572     result = fn(*args, **kwargs)
#    2574 # The code below prevents the output from being displayed
#    2575 # when using magics with decorator @output_can_be_silenced
#    2576 # when the last Python token in the expression is a ';'.
#    2577 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/site-packages/IPython/core/magics/execution.py:1447, in ExecutionMagics.time(self, line, cell, local_ns)
#    1445 if interrupt_occured:
#    1446     if exit_on_interrupt and captured_exception:
# -> 1447         raise captured_exception
#    1448     return
#    1449 return out
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/site-packages/IPython/core/magics/execution.py:1411, in ExecutionMagics.time(self, line, cell, local_ns)
#    1409 st = clock2()
#    1410 try:
# -> 1411     exec(code, glob, local_ns)
#    1412     out = None
#    1413     # multi-line %%time case
#
# File <timed exec>:36
#
# File ~/Documents/GitHub/UK-Tender-Radar/run_tender_radar_mineru.py:448, in run_mineru_extract(pdf_path, output_dir, backend, method, lang, force_refresh, device, formula, table, source)
#     445     proc = subprocess.run(cmd, capture_output=True, text=True)
#     446     return proc.returncode, proc.stdout or "", proc.stderr or ""
# --> 448 rc, out, err = _run_once(pdf_path, method, formula, table)
#     449 text = _load_markdown_text(output_dir) or _load_content_list_text(output_dir) or _load_plain_text(output_dir)
#     450 if rc == 0 and text:
#
# File ~/Documents/GitHub/UK-Tender-Radar/run_tender_radar_mineru.py:445, in run_mineru_extract.<locals>._run_once(path_to_pdf, run_method, run_formula, run_table)
#     433 def _run_once(path_to_pdf: Path, run_method: str, run_formula: bool, run_table: bool) -> tuple[int, str, str]:
#     434     cmd = build_mineru_cmd(
#     435         path_to_pdf,
#     436         output_dir,
#    (...)    443         source=source,
#     444     )
# --> 445     proc = subprocess.run(cmd, capture_output=True, text=True)
#     446     return proc.returncode, proc.stdout or "", proc.stderr or ""
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/subprocess.py:2115, in Popen._communicate(self, input, endtime, orig_timeout)
#    2108     self._check_timeout(endtime, orig_timeout,
#    2109                         stdout, stderr,
#    2110                         skip_check_and_raise=True)
#    2111     raise RuntimeError(  # Impossible :)
#    2112         '_check_timeout(..., skip_check_and_raise=True) '
#    2113         'failed to raise TimeoutExpired.')
# -> 2115 ready = selector.select(timeout)
#    2116 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2118 # XXX Rewrite these to use non-blocking I/O on the file
#    2119 # objects; they are no longer using C stdio!
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
sample_batch_start_ts = time.time()
sample_extraction_rows: List[Dict[str, str]] = []
sample_output_dirs: Dict[str, Path] = {}

sample_companies = [
    c for c in companies if str(c.get("company_number") or "") == SAMPLE_ONLY_COMPANY_NUMBER
]
if not sample_companies:
    raise RuntimeError(f"SAMPLE_ONLY_COMPANY_NUMBER not found in current companies: {SAMPLE_ONLY_COMPANY_NUMBER}")

for c in sample_companies:
    company_start_ts = time.time()
    company_number = str(c.get("company_number") or "")
    company_name = str(c.get("title") or company_number)
    filings = company_filings_by_number.get(company_number, [])
    if not filings:
        continue

    # Choose the smallest-page filing as sample to make this step faster.
    candidates = []
    for filing in filings:
        filing_date = str(filing.get("date") or "")
        meta_url = filing.get("links", {}).get("document_metadata")
        if not meta_url:
            continue
        pdf_url = document_pdf_url(session=session, headers=headers, document_metadata_url=str(meta_url))
        if not pdf_url:
            continue

        sample_pdf_path = DOWNLOAD_DIR / f"{company_number}_{filing_date}.pdf"
        if not sample_pdf_path.exists():
            ok = download_pdf(session=session, headers=headers, pdf_url=pdf_url, output_path=sample_pdf_path)
            if not ok:
                continue
        page_count = get_pdf_page_count(sample_pdf_path)
        rank_pages = page_count if page_count > 0 else 10_000
        candidates.append((rank_pages, filing, sample_pdf_path))

    if not candidates:
        continue

    candidates.sort(key=lambda x: x[0])
    chosen_pages, sample_filing, sample_pdf_path = candidates[0]
    sample_date = str(sample_filing.get("date") or "")

    sample_output_dir = MINERU_OUTPUT_DIR / f"{company_number}_{sample_date}"
    sample_output_dirs[company_number] = sample_output_dir
    sample_text = run_mineru_extract(
        pdf_path=sample_pdf_path,
        output_dir=sample_output_dir,
        backend=MINERU_BACKEND,
        method=MINERU_METHOD,
        lang=MINERU_LANG,
        force_refresh=MINERU_FORCE_REFRESH,
        device=MINERU_DEVICE,
        formula=MINERU_FORMULA,
        table=MINERU_TABLE,
        source=MINERU_SOURCE,
    )
    if not sample_text:
        sample_extraction_rows.append(
            {
                "company_number": company_number,
                "company": company_name,
                "filing_date": sample_date,
                "sample_pages": chosen_pages if chosen_pages < 10_000 else "",
                "status": "failed",
                "log_path": str(sample_output_dir / "mineru_stderr.log"),
                "runtime_seconds": round(time.time() - company_start_ts, 2),
            }
        )
        continue

    sample_auditor, sample_conf = extract_external_auditor(sample_text)
    sample_fee, _ = extract_audit_fee(sample_text)
    sample_currency, sample_unit = detect_currency_and_unit(sample_text)
    sample_year = parse_year(sample_date, sample_text)
    sample_extraction_rows.append(
        {
            "company_number": company_number,
            "company": company_name,
            "filing_date": sample_date,
            "sample_pages": chosen_pages if chosen_pages < 10_000 else "",
            "year": sample_year,
            "external_auditor": sample_auditor,
            "audit_fee": sample_fee,
            "fee_unit": sample_unit,
            "currency": sample_currency,
            "confidence": sample_conf,
            "status": "ok",
            "pdf_path": str(sample_pdf_path),
            "runtime_seconds": round(time.time() - company_start_ts, 2),
        }
    )

sample_extraction_df = pd.DataFrame(sample_extraction_rows)
display(sample_extraction_df)
sample_batch_elapsed = time.time() - sample_batch_start_ts
print(f"[SAMPLE] companies_processed={len(sample_extraction_rows)} runtime_seconds={sample_batch_elapsed:.2f}")
print(f"[SAMPLE] runtime_minutes={sample_batch_elapsed / 60:.2f}")


# # %% 9) Debug MinerU logs for failed sample rows
# if "sample_extraction_df" not in globals() or sample_extraction_df.empty:
#     print("No sample_extraction_df found.")
# else:
#     failed = sample_extraction_df[sample_extraction_df["status"] != "ok"]
#     if failed.empty:
#         print("No failed sample rows.")
#     else:
#         display(failed)
#         for _, row in failed.iterrows():
#             company_number = str(row["company_number"])
#             filing_date = str(row["filing_date"])
#             out_dir = MINERU_OUTPUT_DIR / f"{company_number}_{filing_date}"
#             sample_stdout_log = out_dir / "mineru_stdout.log"
#             sample_stderr_log = out_dir / "mineru_stderr.log"
#             print(f"\n=== {company_number} {filing_date} ===")
#             print(f"stdout log: {sample_stdout_log}")
#             print(f"stderr log: {sample_stderr_log}")
#             if sample_stderr_log.exists():
#                 err_lines = sample_stderr_log.read_text(encoding='utf-8', errors='ignore').splitlines()
#                 print(f"[stderr] lines={len(err_lines)}")
#                 for ln in err_lines[-80:]:
#                     print(ln)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 36
#      34     if not ok:
#      35         continue
# ---> 36 page_count = get_pdf_page_count(sample_pdf_path)
#      37 rank_pages = page_count if page_count > 0 else 10_000
#      38 candidates.append((rank_pages, filing, sample_pdf_path))
#
# NameError: name 'get_pdf_page_count' is not defined

# %%
from __future__ import annotations

import os
import time
from pathlib import Path
from typing import Dict, List

import pandas as pd

from run_tender_radar_mineru import (
    check_mineru_runtime_deps,
    ensure_mineru_cli,
    ensure_companies_csv_from_companies_house,
    is_target_accounts_filing,
    load_active_companies_from_csv,
    run_mineru_extract,
)
from tender_radar import (
    account_filings,
    build_shortlist,
    create_ch_session,
    detect_currency_and_unit,
    document_pdf_url,
    download_pdf,
    extract_audit_fee,
    extract_external_auditor,
    load_api_key_from_file,
    load_dotenv_file,
    make_row,
    parse_year,
    search_companies,
    write_csv,
)


def get_pdf_page_count(pdf_path: Path) -> int:
    try:
        import fitz  # type: ignore
    except Exception:
        return 0
    try:
        doc = fitz.open(str(pdf_path))
        return int(doc.page_count or 0)
    except Exception:
        return 0

# %%
sample_batch_start_ts = time.time()
sample_extraction_rows: List[Dict[str, str]] = []
sample_output_dirs: Dict[str, Path] = {}

sample_companies = [
    c for c in companies if str(c.get("company_number") or "") == SAMPLE_ONLY_COMPANY_NUMBER
]
if not sample_companies:
    raise RuntimeError(f"SAMPLE_ONLY_COMPANY_NUMBER not found in current companies: {SAMPLE_ONLY_COMPANY_NUMBER}")

for c in sample_companies:
    company_start_ts = time.time()
    company_number = str(c.get("company_number") or "")
    company_name = str(c.get("title") or company_number)
    filings = company_filings_by_number.get(company_number, [])
    if not filings:
        continue

    # Choose the smallest-page filing as sample to make this step faster.
    candidates = []
    for filing in filings:
        filing_date = str(filing.get("date") or "")
        meta_url = filing.get("links", {}).get("document_metadata")
        if not meta_url:
            continue
        pdf_url = document_pdf_url(session=session, headers=headers, document_metadata_url=str(meta_url))
        if not pdf_url:
            continue

        sample_pdf_path = DOWNLOAD_DIR / f"{company_number}_{filing_date}.pdf"
        if not sample_pdf_path.exists():
            ok = download_pdf(session=session, headers=headers, pdf_url=pdf_url, output_path=sample_pdf_path)
            if not ok:
                continue
        page_count = get_pdf_page_count(sample_pdf_path)
        rank_pages = page_count if page_count > 0 else 10_000
        candidates.append((rank_pages, filing, sample_pdf_path))

    if not candidates:
        continue

    candidates.sort(key=lambda x: x[0])
    chosen_pages, sample_filing, sample_pdf_path = candidates[0]
    sample_date = str(sample_filing.get("date") or "")

    sample_output_dir = MINERU_OUTPUT_DIR / f"{company_number}_{sample_date}"
    sample_output_dirs[company_number] = sample_output_dir
    sample_text = run_mineru_extract(
        pdf_path=sample_pdf_path,
        output_dir=sample_output_dir,
        backend=MINERU_BACKEND,
        method=MINERU_METHOD,
        lang=MINERU_LANG,
        force_refresh=MINERU_FORCE_REFRESH,
        device=MINERU_DEVICE,
        formula=MINERU_FORMULA,
        table=MINERU_TABLE,
        source=MINERU_SOURCE,
    )
    if not sample_text:
        sample_extraction_rows.append(
            {
                "company_number": company_number,
                "company": company_name,
                "filing_date": sample_date,
                "sample_pages": chosen_pages if chosen_pages < 10_000 else "",
                "status": "failed",
                "log_path": str(sample_output_dir / "mineru_stderr.log"),
                "runtime_seconds": round(time.time() - company_start_ts, 2),
            }
        )
        continue

    sample_auditor, sample_conf = extract_external_auditor(sample_text)
    sample_fee, _ = extract_audit_fee(sample_text)
    sample_currency, sample_unit = detect_currency_and_unit(sample_text)
    sample_year = parse_year(sample_date, sample_text)
    sample_extraction_rows.append(
        {
            "company_number": company_number,
            "company": company_name,
            "filing_date": sample_date,
            "sample_pages": chosen_pages if chosen_pages < 10_000 else "",
            "year": sample_year,
            "external_auditor": sample_auditor,
            "audit_fee": sample_fee,
            "fee_unit": sample_unit,
            "currency": sample_currency,
            "confidence": sample_conf,
            "status": "ok",
            "pdf_path": str(sample_pdf_path),
            "runtime_seconds": round(time.time() - company_start_ts, 2),
        }
    )

sample_extraction_df = pd.DataFrame(sample_extraction_rows)
display(sample_extraction_df)
sample_batch_elapsed = time.time() - sample_batch_start_ts
print(f"[SAMPLE] companies_processed={len(sample_extraction_rows)} runtime_seconds={sample_batch_elapsed:.2f}")
print(f"[SAMPLE] runtime_minutes={sample_batch_elapsed / 60:.2f}")


# # %% 9) Debug MinerU logs for failed sample rows
# if "sample_extraction_df" not in globals() or sample_extraction_df.empty:
#     print("No sample_extraction_df found.")
# else:
#     failed = sample_extraction_df[sample_extraction_df["status"] != "ok"]
#     if failed.empty:
#         print("No failed sample rows.")
#     else:
#         display(failed)
#         for _, row in failed.iterrows():
#             company_number = str(row["company_number"])
#             filing_date = str(row["filing_date"])
#             out_dir = MINERU_OUTPUT_DIR / f"{company_number}_{filing_date}"
#             sample_stdout_log = out_dir / "mineru_stdout.log"
#             sample_stderr_log = out_dir / "mineru_stderr.log"
#             print(f"\n=== {company_number} {filing_date} ===")
#             print(f"stdout log: {sample_stdout_log}")
#             print(f"stderr log: {sample_stderr_log}")
#             if sample_stderr_log.exists():
#                 err_lines = sample_stderr_log.read_text(encoding='utf-8', errors='ignore').splitlines()
#                 print(f"[stderr] lines={len(err_lines)}")
#                 for ln in err_lines[-80:]:
#                     print(ln)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 49
#      47 sample_output_dir = MINERU_OUTPUT_DIR / f"{company_number}_{sample_date}"
#      48 sample_output_dirs[company_number] = sample_output_dir
# ---> 49 sample_text = run_mineru_extract(
#      50     pdf_path=sample_pdf_path,
#      51     output_dir=sample_output_dir,
#      52     backend=MINERU_BACKEND,
#      53     method=MINERU_METHOD,
#      54     lang=MINERU_LANG,
#      55     force_refresh=MINERU_FORCE_REFRESH,
#      56     device=MINERU_DEVICE,
#      57     formula=MINERU_FORMULA,
#      58     table=MINERU_TABLE,
#      59     source=MINERU_SOURCE,
#      60 )
#      61 if not sample_text:
#      62     sample_extraction_rows.append(
#      63         {
#      64             "company_number": company_number,
#    (...)     71         }
#      72     )
#
# File ~/Documents/GitHub/UK-Tender-Radar/run_tender_radar_mineru.py:448, in run_mineru_extract(pdf_path, output_dir, backend, method, lang, force_refresh, device, formula, table, source)
#     445     proc = subprocess.run(cmd, capture_output=True, text=True)
#     446     return proc.returncode, proc.stdout or "", proc.stderr or ""
# --> 448 rc, out, err = _run_once(pdf_path, method, formula, table)
#     449 text = _load_markdown_text(output_dir) or _load_content_list_text(output_dir) or _load_plain_text(output_dir)
#     450 if rc == 0 and text:
#
# File ~/Documents/GitHub/UK-Tender-Radar/run_tender_radar_mineru.py:445, in run_mineru_extract.<locals>._run_once(path_to_pdf, run_method, run_formula, run_table)
#     433 def _run_once(path_to_pdf: Path, run_method: str, run_formula: bool, run_table: bool) -> tuple[int, str, str]:
#     434     cmd = build_mineru_cmd(
#     435         path_to_pdf,
#     436         output_dir,
#    (...)    443         source=source,
#     444     )
# --> 445     proc = subprocess.run(cmd, capture_output=True, text=True)
#     446     return proc.returncode, proc.stdout or "", proc.stderr or ""
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/subprocess.py:2115, in Popen._communicate(self, input, endtime, orig_timeout)
#    2108     self._check_timeout(endtime, orig_timeout,
#    2109                         stdout, stderr,
#    2110                         skip_check_and_raise=True)
#    2111     raise RuntimeError(  # Impossible :)
#    2112         '_check_timeout(..., skip_check_and_raise=True) '
#    2113         'failed to raise TimeoutExpired.')
# -> 2115 ready = selector.select(timeout)
#    2116 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2118 # XXX Rewrite these to use non-blocking I/O on the file
#    2119 # objects; they are no longer using C stdio!
#
# File /opt/miniconda3/envs/audit_fee/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:
